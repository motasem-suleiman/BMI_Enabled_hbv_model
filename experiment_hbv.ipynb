# %%
import pandas as pd
from datetime import datetime
import csv
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# %%
# !ngen catchment_data.geojson "" nexus_data.geojson "" hbv_realization.json
# Out:
# NGen Framework 0.1.0
# Building Nexus collection
# Building Catchment collection
# Catchment topology is dendridic.
# Running Models
# Running timestep 0
# Definition of "au" in "/usr/share/xml/udunits/udunits2-accepted.xml", line 123, overrides prefixed-unit "1.6605402e-45 kilogram"
# Definition of "kt" in "/usr/share/xml/udunits/udunits2-common.xml", line 105, overrides prefixed-unit "1000000 kilogram"
# Definition of "microns" in "/usr/share/xml/udunits/udunits2-common.xml", line 411, overrides prefixed-unit "1e-15 second"
# Definition of "ft" in "/usr/share/xml/udunits/udunits2-common.xml", line 522, overrides prefixed-unit "1e-12 kilogram"
# Definition of "yd" in "/usr/share/xml/udunits/udunits2-common.xml", line 531, overrides prefixed-unit "8.64e-20 second"
# Definition of "pt" in "/usr/share/xml/udunits/udunits2-common.xml", line 785, overrides prefixed-unit "1e-09 kilogram"
# Definition of "at" in "/usr/share/xml/udunits/udunits2-common.xml", line 1250, overrides prefixed-unit "1e-15 kilogram"
# Definition of "ph" in "/usr/share/xml/udunits/udunits2-common.xml", line 1880, overrides prefixed-unit "3.6e-09 second"
# Definition of "nt" in "/usr/share/xml/udunits/udunits2-common.xml", line 1889, overrides prefixed-unit "1e-06 kilogram"
# Running timestep 100
# Running timestep 200
# Running timestep 300
# Running timestep 400
# Running timestep 500
# Running timestep 600
# Running timestep 700
# Running timestep 800
# Running timestep 900
# Running timestep 1000
# Running timestep 1100
# Running timestep 1200
# Running timestep 1300
# Running timestep 1400
# Running timestep 1500
# Running timestep 1600
# Running timestep 1700
# Running timestep 1800
# Running timestep 1900
# Running timestep 2000
# Running timestep 2100
# Running timestep 2200
# Running timestep 2300
# Running timestep 2400
# Running timestep 2500
# Running timestep 2600
# Running timestep 2700
# Running timestep 2800
# Running timestep 2900
# Running timestep 3000
# Running timestep 3100
# Running timestep 3200
# Running timestep 3300
# Running timestep 3400
# Running timestep 3500
# Running timestep 3600
# Running timestep 3700
# Running timestep 3800
# Running timestep 3900
# Running timestep 4000
# Running timestep 4100
# Running timestep 4200
# Running timestep 4300
# Running timestep 4400
# Running timestep 4500
# Running timestep 4600
# Running timestep 4700
# Running timestep 4800
# Running timestep 4900
# Running timestep 5000
# Running timestep 5100
# Running timestep 5200
# Running timestep 5300
# Running timestep 5400
# Running timestep 5500
# Running timestep 5600
# Running timestep 5700
# Running timestep 5800
# Running timestep 5900
# Running timestep 6000
# Running timestep 6100
# Running timestep 6200
# Running timestep 6300
# Running timestep 6400
# Running timestep 6500
# Running timestep 6600
# Running timestep 6700
# Running timestep 6800
# Running timestep 6900
# Running timestep 7000
# Running timestep 7100
# Running timestep 7200
# Running timestep 7300
# Running timestep 7400
# Running timestep 7500
# Running timestep 7600
# Running timestep 7700
# Running timestep 7800
# Running timestep 7900
# Running timestep 8000
# Running timestep 8100
# Running timestep 8200
# Running timestep 8300
# Running timestep 8400
# Running timestep 8500
# Running timestep 8600
# Running timestep 8700
# Running timestep 8800
# Running timestep 8900
# Running timestep 9000
# Running timestep 9100
# Running timestep 9200
# Running timestep 9300
# Running timestep 9400
# Running timestep 9500
# Running timestep 9600
# Running timestep 9700
# Running timestep 9800
# Running timestep 9900
# Running timestep 10000
# Running timestep 10100
# Running timestep 10200
# Running timestep 10300
# Running timestep 10400
# Running timestep 10500
# Running timestep 10600
# Running timestep 10700
# Running timestep 10800
# Running timestep 10900
# Running timestep 11000
# Running timestep 11100
# Running timestep 11200
# Running timestep 11300
# Running timestep 11400
# Running timestep 11500
# Running timestep 11600
# Running timestep 11700
# Running timestep 11800
# Running timestep 11900
# Running timestep 12000
# Running timestep 12100
# Running timestep 12200
# Running timestep 12300
# Running timestep 12400
# Running timestep 12500
# Running timestep 12600
# Running timestep 12700
# Running timestep 12800
# Running timestep 12900
# Running timestep 13000
# Running timestep 13100
# Running timestep 13200
# Running timestep 13300
# Running timestep 13400
# Running timestep 13500
# Running timestep 13600
# Running timestep 13700
# Running timestep 13800
# Running timestep 13900
# Running timestep 14000
# Running timestep 14100
# Running timestep 14200
# Running timestep 14300
# Running timestep 14400
# Running timestep 14500
# Running timestep 14600
# Finished 14610 timesteps.

# %%
# get the data for catchment 67
df = pd.read_csv('cat-67.csv')
df['Time'] = df['Time'].map(lambda x: datetime.strptime(str(x), '%Y-%m-%d %H:%M:%S'))
print (df)
# Out:
#        Time Step       Time  water_output
# 0              0 1981-01-01      0.000000
# 1              1 1981-01-02      0.000000
# 2              2 1981-01-03      0.000000
# 3              3 1981-01-04      0.000000
# 4              4 1981-01-05      0.000000
# ...          ...        ...           ...
# 14605      14605 2020-12-27      1.087509
# 14606      14606 2020-12-28      1.053872
# 14607      14607 2020-12-29      1.021276
# 14608      14608 2020-12-30      0.989689
# 14609      14609 2020-12-31      0.959078
#
# [14610 rows x 3 columns]

# %%
# plot the results
plt.plot(df["Time"],df["water_output"])
# beautify the x-labels
plt.gcf().autofmt_xdate()

plt.show()
